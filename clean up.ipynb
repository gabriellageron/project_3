# %%
import pandas as pd
from sqlalchemy import create_engine
import json

# %%
file = 'Stock_List.csv'

# %%
originalrecords_df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
originalrecords_df.columns
# Out:
# Index(['Symbol', 'Name', 'LastSale', 'MarketCap', 'IPOyear', 'Sector',
#        'industry', 'Summary Quote'],
#       dtype='object')

# %%
originalrecords_df.head()
# Out:
#   Symbol                         Name  LastSale MarketCap  IPOyear  \
# 0      A   Agilent Technologies, Inc.     84.45    $26.1B   1999.0
# 1     AA            Alcoa Corporation     20.98    $3.89B   2016.0
# 2    AAN           Aaron&#39;s,  Inc.     59.66    $4.01B      NaN
# 3    AAP       Advance Auto Parts Inc    153.50   $10.63B      NaN
# 4    AAT  American Assets Trust, Inc.     44.89    $2.69B   2011.0
#
#               Sector                                          industry  \
# 0      Capital Goods  Biotechnology: Laboratory Analytical Instruments
# 1   Basic Industries                                          Aluminum
# 2         Technology                   Diversified Commercial Services
# 3  Consumer Services                            Other Specialty Stores
# 4  Consumer Services                     Real Estate Investment Trusts
#
#                        Summary Quote
# 0    https://old.nasdaq.com/symbol/a
# 1   https://old.nasdaq.com/symbol/aa
# ...

# %%
del originalrecords_df['Summary Quote']
originalrecords_df.head()
# Out:
#   Symbol                         Name  LastSale MarketCap  IPOyear  \
# 0      A   Agilent Technologies, Inc.     84.45    $26.1B   1999.0
# 1     AA            Alcoa Corporation     20.98    $3.89B   2016.0
# 2    AAN           Aaron&#39;s,  Inc.     59.66    $4.01B      NaN
# 3    AAP       Advance Auto Parts Inc    153.50   $10.63B      NaN
# 4    AAT  American Assets Trust, Inc.     44.89    $2.69B   2011.0
#
#               Sector                                          industry
# 0      Capital Goods  Biotechnology: Laboratory Analytical Instruments
# 1   Basic Industries                                          Aluminum
# 2         Technology                   Diversified Commercial Services
# 3  Consumer Services                            Other Specialty Stores
# 4  Consumer Services                     Real Estate Investment Trusts

# %%
originalrecords_df['Sector'].value_counts()
# Out:
# Consumer Services        434
# Finance                  346
# Public Utilities         197
# Capital Goods            189
# Basic Industries         186
# Energy                   186
# Technology               177
# Consumer Non-Durables    105
# Health Care              104
# Consumer Durables         63
# Transportation            62
# Miscellaneous             49
# Name: Sector, dtype: int64

# %%
MaxLastSale_df = originalrecords_df.sort_values("LastSale", ascending=False)
MaxLastSale_df.head(100)
# Out:
#      Symbol                                           Name   LastSale  \
# 2074    NVR                                      NVR, Inc.  3860.0000
# 474    CABO                                Cable One, Inc.  1516.2800
# 281   BAC^L                    Bank of America Corporation  1474.3300
# 3018  WFC^L                          Wells Fargo & Company  1444.0000
# 268     AZO                                 AutoZone, Inc.  1225.2200
# 514   CCI^A         Crown Castle International Corporation  1221.3800
# 808   DHR^A                            Danaher Corporation  1168.0000
# 1813    MKL                             Markel Corporation  1138.9200
# 3074    WTM          White Mountains Insurance Group, Ltd.  1115.6200
# 1149  FTV^A                            Fortive Corporation   977.7925
# 2910  USB^A                                   U.S. Bancorp   862.0001
# 622     CMG                   Chipotle Mexican Grill, Inc.   822.7900
# ...

# %%
MaxLastSale_df.to_csv('MaxLastSale_df.csv')
